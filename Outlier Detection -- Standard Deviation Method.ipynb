# %% [markdown]
# # Importing Libraires

# %%
import pandas as pd
from scipy.io import loadmat

# %% [markdown]
# # Loading Exercise 1

# %%
Exercise_1 = loadmat(r"S1_E1_A1.mat")

# %%
print(Exercise_1)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Mon Jan 14 02:36:34 2013', '__version__': '1.0', '__globals__': [], 'emg': array([[-2.8512097e-06,  3.3552608e-06,  1.5988660e-06, ...,
#          1.4699236e-06, -5.6090889e-06,  4.0180992e-05],
#        [-4.6977384e-06,  3.3552124e-06,  1.4304406e-06, ...,
#          2.4781623e-06, -3.2593930e-06,  4.9580311e-05],
#        [-2.6837340e-06,  4.0265595e-06,  9.2631649e-07, ...,
#          2.4793057e-06, -7.0452693e-08,  4.7062331e-05],
#        ...,
#        [ 4.6579542e-05, -9.4416337e-06, -6.4931774e-06, ...,
#          5.3471636e-06, -1.9315494e-06,  1.6664750e-04],
#        [ 9.5255244e-05,  2.4758735e-06, -1.6255494e-06, ...,
#          6.8578074e-06, -1.2603056e-06,  8.5408486e-05],
#        [ 9.0051348e-05,  8.1829576e-06,  7.2433983e-07, ...,
#          4.6757668e-06, -2.4354026e-06,  1.1051290e-05]], dtype=float32), 'acc': array([[ 0.14023736,  0.9540544 ,  0.27923268, ...,  0.875372  ,
# ...

# %%
print(Exercise_1.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'emg', 'acc', 'stimulus', 'glove', 'inclin', 'subject', 'exercise', 'repetition', 'restimulus', 'rerepetition'])

# %%
emg_1 = Exercise_1['emg']
stimulus_1 = Exercise_1['stimulus']
restimulus_1 = Exercise_1['restimulus']
repetition_1 = Exercise_1['repetition']
rerepetition_1 = Exercise_1['rerepetition']

# %% [markdown]
# # DataFramae

# %% [markdown]
# ### Convert the dictionary into DataFrame

# %%
# Custom Column Names

# %%
df_1= pd.DataFrame(emg_1, 
                  columns = ['Emg1','Emg2','Emg3','Emg4','Emg5','Emg6','Emg7','Emg8','Emg9','Emg10','Emg11','Emg12'])

# %%
df_1
# Out:
#              Emg1          Emg2          Emg3          Emg4      Emg5  \
# 0       -0.000003  3.355261e-06  1.598866e-06 -1.394234e-06 -0.000002
# 1       -0.000005  3.355212e-06  1.430441e-06 -3.072682e-06 -0.000003
# 2       -0.000003  4.026560e-06  9.263165e-07 -5.422526e-06 -0.000004
# 3        0.000002  2.851566e-06  7.578904e-07 -6.597427e-06 -0.000004
# 4        0.000004  6.694763e-07  1.764409e-06 -5.422437e-06 -0.000006
# ...           ...           ...           ...           ...       ...
# 1808326 -0.000077 -3.075891e-05 -1.203220e-05 -3.283249e-06 -0.000004
# 1808327 -0.000032 -2.370903e-05 -1.136081e-05 -2.275687e-06 -0.000001
# 1808328  0.000047 -9.441634e-06 -6.493177e-06 -5.967306e-07 -0.000001
# 1808329  0.000095  2.475874e-06 -1.625549e-06  2.429787e-07 -0.000004
# 1808330  0.000090  8.182958e-06  7.243398e-07  1.754087e-06 -0.000003
#
#                  Emg6          Emg7          Emg8          Emg9         Emg10  \
# ...

# %%
repetition_1 = pd.DataFrame(repetition_1)
rerepetition_1 = pd.DataFrame(rerepetition_1)
stimulus_1 = pd.DataFrame(stimulus_1)
restimulus_1 = pd.DataFrame(restimulus_1)

# %% [markdown]
# ### Adding new column to existing DataFrame

# %%
df_1['repetition'] = repetition_1
df_1['rerepetition'] = rerepetition_1
df_1['stimulus'] = stimulus_1
df_1['restimulus'] = restimulus_1

# %% [markdown]
# # Final Output of Exercise 1 DataFrame

# %%
df_1
# Out:
#              Emg1          Emg2          Emg3          Emg4      Emg5  \
# 0       -0.000003  3.355261e-06  1.598866e-06 -1.394234e-06 -0.000002
# 1       -0.000005  3.355212e-06  1.430441e-06 -3.072682e-06 -0.000003
# 2       -0.000003  4.026560e-06  9.263165e-07 -5.422526e-06 -0.000004
# 3        0.000002  2.851566e-06  7.578904e-07 -6.597427e-06 -0.000004
# 4        0.000004  6.694763e-07  1.764409e-06 -5.422437e-06 -0.000006
# ...           ...           ...           ...           ...       ...
# 1808326 -0.000077 -3.075891e-05 -1.203220e-05 -3.283249e-06 -0.000004
# 1808327 -0.000032 -2.370903e-05 -1.136081e-05 -2.275687e-06 -0.000001
# 1808328  0.000047 -9.441634e-06 -6.493177e-06 -5.967306e-07 -0.000001
# 1808329  0.000095  2.475874e-06 -1.625549e-06  2.429787e-07 -0.000004
# 1808330  0.000090  8.182958e-06  7.243398e-07  1.754087e-06 -0.000003
#
#                  Emg6          Emg7          Emg8          Emg9         Emg10  \
# ...

# %%
print(df_1.describe(include = 'all'))
print("************************************************************************************************************")
print(df_1.info())
print("************************************************************************************************************")
print("Shape of the Dataset is", df_1.shape)
# Out:
#                Emg1          Emg2          Emg3          Emg4          Emg5  \
# count  1.808331e+06  1.808331e+06  1.808331e+06  1.808331e+06  1.808331e+06
# mean   4.808046e-09 -7.357037e-10 -4.197198e-07  2.112359e-09 -1.398382e-10
# std    4.108262e-05  2.755114e-05  4.318822e-05  4.572169e-05  1.158778e-05
# min   -1.414742e-03 -1.417531e-03 -5.499916e-03 -1.693960e-03 -3.886087e-04
# 25%   -4.978786e-06 -3.936091e-06 -3.251690e-06 -2.873654e-06 -2.693712e-06
# 50%    1.466555e-07  3.258234e-07  6.282035e-09  8.234291e-08  7.752094e-08
# 75%    5.056879e-06  4.663832e-06  3.371931e-06  3.101591e-06  2.885123e-06
# max    1.247256e-03  5.895796e-04  5.498070e-03  2.179232e-03  3.563007e-04
#
#                Emg6          Emg7          Emg8          Emg9         Emg10  \
# count  1.808331e+06  1.808331e+06  1.808331e+06  1.808331e+06  1.808331e+06
# mean   8.477333e-10  2.029871e-09  2.024931e-08  9.771852e-09 -4.893191e-07
# ...

# %% [markdown]
# #  Loading Exercise 2

# %%
Exercise_2 = loadmat(r"S1_E2_A1.mat")

# %%
print(Exercise_2)
print("************************************************************************************************************")
print(Exercise_2.keys())
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Mon Jan 14 02:50:34 2013', '__version__': '1.0', '__globals__': [], 'emg': array([[ 8.8234651e-07,  1.0717506e-06,  2.0498924e-06, ...,
#          1.8509678e-05, -7.0236968e-07,  8.1215067e-06],
#        [ 1.7214358e-06,  1.4072614e-06,  5.3924919e-07, ...,
#          1.4480399e-05, -2.0452155e-06,  9.4638763e-06],
#        [-1.2506415e-07,  2.0784701e-06, -1.3070925e-06, ...,
#          8.7726285e-06, -3.7237605e-06,  1.1141945e-05],
#        ...,
#        [ 1.2604414e-05,  3.4272251e-08, -2.9844853e-07, ...,
#         -1.0334954e-05, -9.0856147e-06, -2.2172696e-06],
#        [ 4.8833322e-06, -6.3691493e-07, -1.8085398e-06, ...,
#         -4.9637788e-06, -1.0932163e-05, -1.0424706e-06],
#        [ 2.7012754e-06, -1.6438012e-06, -4.6614246e-06, ...,
#          1.4842431e-05, -1.1603769e-05,  1.3072749e-06]], dtype=float32), 'acc': array([[ 0.09994001,  0.9217136 ,  0.35475552, ...,  0.84354025,
# ...

# %%
emg_2 = Exercise_2['emg']
stimulus_2 = Exercise_2['stimulus']
restimulus_2 = Exercise_2['restimulus']
repetition_2 = Exercise_2['repetition']
rerepetition_2 = Exercise_2['rerepetition']

# %% [markdown]
# # DataFramae

# %% [markdown]
# ### Convert the dictionary into DataFrame

# %%
df_2= pd.DataFrame(emg_2, 
                  columns = ['Emg1','Emg2','Emg3','Emg4','Emg5','Emg6','Emg7','Emg8','Emg9','Emg10','Emg11','Emg12'])

# %%
df_2
# Out:
#                  Emg1          Emg2          Emg3          Emg4          Emg5  \
# 0        8.823465e-07  1.071751e-06  2.049892e-06 -6.107421e-06 -1.439325e-06
# 1        1.721436e-06  1.407261e-06  5.392492e-07 -2.918245e-06 -3.146832e-07
# 2       -1.250641e-07  2.078470e-06 -1.307092e-06 -1.911109e-06 -1.177758e-06
# 3       -1.300164e-06 -1.037563e-07 -2.985585e-06 -1.407522e-06 -2.726635e-06
# 4       -6.289250e-07 -1.950286e-06 -4.160529e-06 -4.003859e-07 -2.034733e-06
# ...               ...           ...           ...           ...           ...
# 2553284  5.775589e-05  3.055139e-06 -3.320837e-06  7.326447e-07  5.578875e-07
# 2553285  3.090000e-05  2.048252e-06 -1.473945e-06  1.068368e-06  2.798024e-06
# 2553286  1.260441e-05  3.427225e-08 -2.984485e-07  1.571939e-06  4.765528e-06
# 2553287  4.883332e-06 -6.369149e-07 -1.808540e-06  1.907662e-06  3.410625e-06
# 2553288  2.701275e-06 -1.643801e-06 -4.661425e-06  9.005915e-07  6.152590e-07
#
# ...

# %%
repetition_2 = pd.DataFrame(repetition_2)
rerepetition_2 = pd.DataFrame(rerepetition_2)
stimulus_2 = pd.DataFrame(stimulus_2)
restimulus_2 = pd.DataFrame(restimulus_2)

# %% [markdown]
# ### Adding new column to existing DataFrame

# %%
df_2['repetition'] = repetition_2
df_2['rerepetition'] = rerepetition_2
df_2['stimulus'] = stimulus_2
df_2['restimulus'] = restimulus_2

# %% [markdown]
# # Final Output of Exercise 2 DataFrame

# %%
df_2
# Out:
#                  Emg1          Emg2          Emg3          Emg4          Emg5  \
# 0        8.823465e-07  1.071751e-06  2.049892e-06 -6.107421e-06 -1.439325e-06
# 1        1.721436e-06  1.407261e-06  5.392492e-07 -2.918245e-06 -3.146832e-07
# 2       -1.250641e-07  2.078470e-06 -1.307092e-06 -1.911109e-06 -1.177758e-06
# 3       -1.300164e-06 -1.037563e-07 -2.985585e-06 -1.407522e-06 -2.726635e-06
# 4       -6.289250e-07 -1.950286e-06 -4.160529e-06 -4.003859e-07 -2.034733e-06
# ...               ...           ...           ...           ...           ...
# 2553284  5.775589e-05  3.055139e-06 -3.320837e-06  7.326447e-07  5.578875e-07
# 2553285  3.090000e-05  2.048252e-06 -1.473945e-06  1.068368e-06  2.798024e-06
# 2553286  1.260441e-05  3.427225e-08 -2.984485e-07  1.571939e-06  4.765528e-06
# 2553287  4.883332e-06 -6.369149e-07 -1.808540e-06  1.907662e-06  3.410625e-06
# 2553288  2.701275e-06 -1.643801e-06 -4.661425e-06  9.005915e-07  6.152590e-07
#
# ...

# %%
print(df_2.describe(include = 'all'))
print("************************************************************************************************************")
print(df_2.info())
print("************************************************************************************************************")
print("Shape of the Dataset is", df_2.shape)
# Out:
#                Emg1          Emg2          Emg3          Emg4          Emg5  \
# count  2.553289e+06  2.553289e+06  2.553289e+06  2.553289e+06  2.553289e+06
# mean  -3.783633e-09 -1.766764e-09 -3.144518e-07  2.532337e-09 -2.645477e-09
# std    4.856849e-05  2.570469e-05  2.569570e-05  2.548249e-05  8.364394e-06
# min   -2.469218e-03 -1.071370e-03 -1.038987e-03 -8.659597e-04 -2.472825e-04
# 25%   -4.493430e-06 -3.021946e-06 -2.734504e-06 -2.592521e-06 -2.640879e-06
# 50%    2.665453e-07  2.592740e-07  2.284755e-08  6.688079e-08  1.284394e-08
# 75%    4.975688e-06  3.639089e-06  2.834253e-06  2.779692e-06  2.712956e-06
# max    2.994443e-03  7.062866e-04  1.023766e-03  7.224317e-04  2.776774e-04
#
#                Emg6          Emg7          Emg8          Emg9         Emg10  \
# count  2.553289e+06  2.553289e+06  2.553289e+06  2.553289e+06  2.553289e+06
# mean  -9.246361e-10  4.055112e-09  1.821793e-08 -5.142148e-10 -5.198042e-07
# ...

# %% [markdown]
# #  Loading Exercise 3

# %%
Exercise_3 = loadmat(r"S1_E3_A1.mat")

# %%
print(Exercise_3)
print("************************************************************************************************************")
print(Exercise_3.keys())
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Mon Jan 11 15:55:58 2016', '__version__': '1.0', '__globals__': [], 'emg': array([[-1.3327014e-05, -4.4854241e-06, -3.0063632e-06, ...,
#         -4.0443897e-06,  9.6489075e-08, -5.3600692e-05],
#        [-2.6083462e-05, -5.8282972e-06, -1.6635695e-06, ...,
#         -3.3730332e-06, -1.2463578e-06, -4.5377135e-05],
#        [-3.5986468e-05, -6.4997744e-06, -2.5028157e-06, ...,
#         -1.6945817e-06, -1.0785604e-06, -3.4467994e-05],
#        ...,
#        [ 4.4123990e-06,  2.1017595e-06, -6.8290246e-06, ...,
#         -1.2507878e-06,  5.0843721e-07, -1.3762069e-05],
#        [ 5.2516430e-06,  1.9339172e-06, -5.6540798e-06, ...,
#         -7.4752575e-07, -1.6300208e-07, -1.1746518e-05],
#        [ 5.0837916e-06,  2.6053222e-06, -4.1434369e-06, ...,
#         -2.5941536e-06,  3.4050362e-07, -1.4095049e-05]], dtype=float32), 'acc': array([[ 0.10907351,  1.0349065 , -0.23560148, ...,  0.6351672 ,
# ...

# %%
emg_3 = Exercise_3['emg']
stimulus_3 = Exercise_3['stimulus']
restimulus_3 = Exercise_3['restimulus']
repetition_3 = Exercise_3['repetition']
rerepetition_3 = Exercise_3['rerepetition']

# %% [markdown]
# # DataFramae

# %%
df_3= pd.DataFrame(emg_3, 
                  columns = ['Emg1','Emg2','Emg3','Emg4','Emg5','Emg6','Emg7','Emg8','Emg9','Emg10','Emg11','Emg12'])

# %%
df_3
# Out:
#                 Emg1          Emg2      Emg3          Emg4          Emg5  \
# 0      -1.332701e-05 -4.485424e-06 -0.000003  2.056291e-06  2.317538e-07
# 1      -2.608346e-05 -5.828297e-06 -0.000002 -1.257783e-07  5.675562e-07
# 2      -3.598647e-05 -6.499774e-06 -0.000003 -1.972148e-06  9.033584e-07
# 3      -2.944025e-05 -1.967925e-06 -0.000004 -1.972176e-06  3.085502e-06
# 4      -7.955457e-06  1.062069e-05 -0.000005 -7.972596e-07  5.267647e-06
# ...              ...           ...       ...           ...           ...
# 877068 -6.230766e-07  5.911040e-07 -0.000005 -1.236290e-06 -2.134746e-06
# 877069  2.901756e-06  1.766055e-06 -0.000006 -1.404029e-06 -2.187698e-06
# 877070  4.412399e-06  2.101759e-06 -0.000007 -3.968205e-07 -1.896385e-06
# 877071  5.251643e-06  1.933917e-06 -0.000006  2.746891e-07 -1.210498e-07
# 877072  5.083792e-06  2.605322e-06 -0.000004 -7.322931e-07  1.618387e-07
#
#                 Emg6          Emg7      Emg8          Emg9         Emg10  \
# ...

# %%
repetition_3 = pd.DataFrame(repetition_3)
rerepetition_3 = pd.DataFrame(rerepetition_3)
stimulus_3 = pd.DataFrame(stimulus_3)
restimulus_3 = pd.DataFrame(restimulus_3)

# %% [markdown]
# # Adding new column to existing DataFrame

# %%
df_3['repetition'] = repetition_3
df_3['rerepetition'] = rerepetition_3
df_3['stimulus'] = stimulus_3
df_3['restimulus'] = restimulus_3

# %% [markdown]
# # Final Output of Exercise 3 DataFrame

# %%
df_3
# Out:
#                 Emg1          Emg2      Emg3          Emg4          Emg5  \
# 0      -1.332701e-05 -4.485424e-06 -0.000003  2.056291e-06  2.317538e-07
# 1      -2.608346e-05 -5.828297e-06 -0.000002 -1.257783e-07  5.675562e-07
# 2      -3.598647e-05 -6.499774e-06 -0.000003 -1.972148e-06  9.033584e-07
# 3      -2.944025e-05 -1.967925e-06 -0.000004 -1.972176e-06  3.085502e-06
# 4      -7.955457e-06  1.062069e-05 -0.000005 -7.972596e-07  5.267647e-06
# ...              ...           ...       ...           ...           ...
# 877068 -6.230766e-07  5.911040e-07 -0.000005 -1.236290e-06 -2.134746e-06
# 877069  2.901756e-06  1.766055e-06 -0.000006 -1.404029e-06 -2.187698e-06
# 877070  4.412399e-06  2.101759e-06 -0.000007 -3.968205e-07 -1.896385e-06
# 877071  5.251643e-06  1.933917e-06 -0.000006  2.746891e-07 -1.210498e-07
# 877072  5.083792e-06  2.605322e-06 -0.000004 -7.322931e-07  1.618387e-07
#
#                 Emg6          Emg7      Emg8          Emg9         Emg10  \
# ...

# %%
print(df_3.describe(include = 'all'))
print("************************************************************************************************************")
print(df_3.info())
print("************************************************************************************************************")
print("Shape of the Dataset is", df_3.shape)
# Out:
#                Emg1          Emg2          Emg3          Emg4          Emg5  \
# count  8.770730e+05  8.770730e+05  8.770730e+05  8.770730e+05  8.770730e+05
# mean  -2.767227e-09  5.444661e-09 -9.746166e-07 -3.886149e-09  7.929893e-09
# std    4.589474e-05  2.637576e-05  6.746632e-05  4.567456e-05  1.424528e-05
# min   -1.278998e-03 -4.330944e-04 -1.072221e-03 -7.138526e-04 -1.571049e-04
# 25%   -8.014984e-06 -5.933041e-06 -1.170651e-05 -7.961318e-06 -4.261320e-06
# 50%    4.356404e-07  1.046479e-07  2.555978e-07  3.911667e-07  1.855226e-07
# 75%    1.020736e-05  6.174931e-06  1.745632e-05  9.115118e-06  4.762721e-06
# max    1.212735e-03  3.682558e-04  8.350500e-04  8.617164e-04  1.768940e-04
#
#                Emg6          Emg7          Emg8          Emg9         Emg10  \
# count  8.770730e+05  8.770730e+05  8.770730e+05  8.770730e+05  8.770730e+05
# mean  -2.529894e-10 -1.022754e-08  1.149016e-08 -1.289686e-08 -5.592727e-08
# ...

# %% [markdown]
# # Add a row from one dataframe to other dataframe

# %% [markdown]
# https://appdividend.com/2020/01/22/python-pandas-how-to-add-rows-in-dataframe/#:~:text=Python%20Pandas%20dataframe%20append(),or%20add%20a%20new%20row.

# %%
df_1_2 = df_1.append(df_2, ignore_index=True)

# %%
df_1_2
# Out:
#              Emg1          Emg2          Emg3          Emg4          Emg5  \
# 0       -0.000003  3.355261e-06  1.598866e-06 -1.394234e-06 -2.082012e-06
# 1       -0.000005  3.355212e-06  1.430441e-06 -3.072682e-06 -3.063038e-06
# 2       -0.000003  4.026560e-06  9.263165e-07 -5.422526e-06 -3.695910e-06
# 3        0.000002  2.851566e-06  7.578904e-07 -6.597427e-06 -3.937123e-06
# 4        0.000004  6.694763e-07  1.764409e-06 -5.422437e-06 -5.652943e-06
# ...           ...           ...           ...           ...           ...
# 4361615  0.000058  3.055139e-06 -3.320837e-06  7.326447e-07  5.578875e-07
# 4361616  0.000031  2.048252e-06 -1.473945e-06  1.068368e-06  2.798024e-06
# 4361617  0.000013  3.427225e-08 -2.984485e-07  1.571939e-06  4.765528e-06
# 4361618  0.000005 -6.369149e-07 -1.808540e-06  1.907662e-06  3.410625e-06
# 4361619  0.000003 -1.643801e-06 -4.661425e-06  9.005915e-07  6.152590e-07
#
#                  Emg6          Emg7          Emg8          Emg9     Emg10  \
# ...

# %%
df_1_2_3 = df_1_2.append(df_3, ignore_index=True)

# %% [markdown]
# # Final Output

# %%
df_1_2_3
# Out:
#                  Emg1          Emg2          Emg3          Emg4          Emg5  \
# 0       -2.851210e-06  3.355261e-06  1.598866e-06 -1.394234e-06 -2.082012e-06
# 1       -4.697738e-06  3.355212e-06  1.430441e-06 -3.072682e-06 -3.063038e-06
# 2       -2.683734e-06  4.026560e-06  9.263165e-07 -5.422526e-06 -3.695910e-06
# 3        2.183707e-06  2.851566e-06  7.578904e-07 -6.597427e-06 -3.937123e-06
# 4        4.197711e-06  6.694763e-07  1.764409e-06 -5.422437e-06 -5.652943e-06
# ...               ...           ...           ...           ...           ...
# 5238688 -6.230766e-07  5.911040e-07 -5.486231e-06 -1.236290e-06 -2.134746e-06
# 5238689  2.901756e-06  1.766055e-06 -6.493326e-06 -1.404029e-06 -2.187698e-06
# 5238690  4.412399e-06  2.101759e-06 -6.829025e-06 -3.968205e-07 -1.896385e-06
# 5238691  5.251643e-06  1.933917e-06 -5.654080e-06  2.746891e-07 -1.210498e-07
# 5238692  5.083792e-06  2.605322e-06 -4.143437e-06 -7.322931e-07  1.618387e-07
#
# ...

# %%
print(df_1_2_3.describe(include = 'all'))
print("************************************************************************************************************")
print(df_1_2_3.info())
print("************************************************************************************************************")
print("Shape of the Dataset is", df_1_2_3.shape)
# Out:
#                Emg1          Emg2          Emg3          Emg4          Emg5  \
# count  5.238693e+06  5.238693e+06  5.238693e+06  5.238693e+06  5.238693e+06
# mean  -6.480936e-10 -2.034878e-10 -4.613399e-07  1.312724e-09 -1.003211e-11
# std    4.555207e-05  2.639384e-05  4.149183e-05  3.715778e-05  1.064855e-05
# min   -2.469218e-03 -1.417531e-03 -5.499916e-03 -1.693960e-03 -3.886087e-04
# 25%   -5.018146e-06 -3.633920e-06 -3.353354e-06 -3.031360e-06 -2.837172e-06
# 50%    2.428014e-07  2.583237e-07  3.509816e-08  1.009616e-07  5.676338e-08
# 75%    5.477814e-06  4.253370e-06  3.563590e-06  3.305496e-06  3.007697e-06
# max    2.994443e-03  7.062866e-04  5.498070e-03  2.179232e-03  3.563007e-04
#
#                Emg6          Emg7          Emg8          Emg9         Emg10  \
# count  5.238693e+06  5.238693e+06  5.238693e+06  5.238693e+06  5.238693e+06
# mean  -2.004598e-10  9.648298e-10  1.779410e-08  9.631427e-10 -4.316631e-07
# ...

# %% [markdown]
# # Compersion

# %%
df_1
# Out:
#              Emg1          Emg2          Emg3          Emg4      Emg5  \
# 0       -0.000003  3.355261e-06  1.598866e-06 -1.394234e-06 -0.000002
# 1       -0.000005  3.355212e-06  1.430441e-06 -3.072682e-06 -0.000003
# 2       -0.000003  4.026560e-06  9.263165e-07 -5.422526e-06 -0.000004
# 3        0.000002  2.851566e-06  7.578904e-07 -6.597427e-06 -0.000004
# 4        0.000004  6.694763e-07  1.764409e-06 -5.422437e-06 -0.000006
# ...           ...           ...           ...           ...       ...
# 1808326 -0.000077 -3.075891e-05 -1.203220e-05 -3.283249e-06 -0.000004
# 1808327 -0.000032 -2.370903e-05 -1.136081e-05 -2.275687e-06 -0.000001
# 1808328  0.000047 -9.441634e-06 -6.493177e-06 -5.967306e-07 -0.000001
# 1808329  0.000095  2.475874e-06 -1.625549e-06  2.429787e-07 -0.000004
# 1808330  0.000090  8.182958e-06  7.243398e-07  1.754087e-06 -0.000003
#
#                  Emg6          Emg7          Emg8          Emg9         Emg10  \
# ...

# %%
df_2
# Out:
#                  Emg1          Emg2          Emg3          Emg4          Emg5  \
# 0        8.823465e-07  1.071751e-06  2.049892e-06 -6.107421e-06 -1.439325e-06
# 1        1.721436e-06  1.407261e-06  5.392492e-07 -2.918245e-06 -3.146832e-07
# 2       -1.250641e-07  2.078470e-06 -1.307092e-06 -1.911109e-06 -1.177758e-06
# 3       -1.300164e-06 -1.037563e-07 -2.985585e-06 -1.407522e-06 -2.726635e-06
# 4       -6.289250e-07 -1.950286e-06 -4.160529e-06 -4.003859e-07 -2.034733e-06
# ...               ...           ...           ...           ...           ...
# 2553284  5.775589e-05  3.055139e-06 -3.320837e-06  7.326447e-07  5.578875e-07
# 2553285  3.090000e-05  2.048252e-06 -1.473945e-06  1.068368e-06  2.798024e-06
# 2553286  1.260441e-05  3.427225e-08 -2.984485e-07  1.571939e-06  4.765528e-06
# 2553287  4.883332e-06 -6.369149e-07 -1.808540e-06  1.907662e-06  3.410625e-06
# 2553288  2.701275e-06 -1.643801e-06 -4.661425e-06  9.005915e-07  6.152590e-07
#
# ...

# %%
df_3
# Out:
#                 Emg1          Emg2      Emg3          Emg4          Emg5  \
# 0      -1.332701e-05 -4.485424e-06 -0.000003  2.056291e-06  2.317538e-07
# 1      -2.608346e-05 -5.828297e-06 -0.000002 -1.257783e-07  5.675562e-07
# 2      -3.598647e-05 -6.499774e-06 -0.000003 -1.972148e-06  9.033584e-07
# 3      -2.944025e-05 -1.967925e-06 -0.000004 -1.972176e-06  3.085502e-06
# 4      -7.955457e-06  1.062069e-05 -0.000005 -7.972596e-07  5.267647e-06
# ...              ...           ...       ...           ...           ...
# 877068 -6.230766e-07  5.911040e-07 -0.000005 -1.236290e-06 -2.134746e-06
# 877069  2.901756e-06  1.766055e-06 -0.000006 -1.404029e-06 -2.187698e-06
# 877070  4.412399e-06  2.101759e-06 -0.000007 -3.968205e-07 -1.896385e-06
# 877071  5.251643e-06  1.933917e-06 -0.000006  2.746891e-07 -1.210498e-07
# 877072  5.083792e-06  2.605322e-06 -0.000004 -7.322931e-07  1.618387e-07
#
#                 Emg6          Emg7      Emg8          Emg9         Emg10  \
# ...

# %%
df_1_2_3
# Out:
#                  Emg1          Emg2          Emg3          Emg4          Emg5  \
# 0       -2.851210e-06  3.355261e-06  1.598866e-06 -1.394234e-06 -2.082012e-06
# 1       -4.697738e-06  3.355212e-06  1.430441e-06 -3.072682e-06 -3.063038e-06
# 2       -2.683734e-06  4.026560e-06  9.263165e-07 -5.422526e-06 -3.695910e-06
# 3        2.183707e-06  2.851566e-06  7.578904e-07 -6.597427e-06 -3.937123e-06
# 4        4.197711e-06  6.694763e-07  1.764409e-06 -5.422437e-06 -5.652943e-06
# ...               ...           ...           ...           ...           ...
# 5238688 -6.230766e-07  5.911040e-07 -5.486231e-06 -1.236290e-06 -2.134746e-06
# 5238689  2.901756e-06  1.766055e-06 -6.493326e-06 -1.404029e-06 -2.187698e-06
# 5238690  4.412399e-06  2.101759e-06 -6.829025e-06 -3.968205e-07 -1.896385e-06
# 5238691  5.251643e-06  1.933917e-06 -5.654080e-06  2.746891e-07 -1.210498e-07
# 5238692  5.083792e-06  2.605322e-06 -4.143437e-06 -7.322931e-07  1.618387e-07
#
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, classification_report

# %%
raw_data = df_1_2_3
raw_data.sample(5)
# Out:
#                  Emg1          Emg2          Emg3          Emg4          Emg5  \
# 1024695 -6.821586e-05 -1.487942e-06  1.037308e-04  4.959208e-05 -1.549677e-06
# 712644  -1.981929e-07  7.141257e-07  1.333042e-06  1.973458e-06 -1.243437e-06
# 4445021 -2.183655e-06  1.356449e-06  1.556269e-06  9.076700e-07  2.658179e-06
# 696525   1.624512e-06 -2.206283e-08 -7.339519e-07  2.079768e-06 -8.005325e-07
# 2734628  2.907672e-05  2.677165e-06  8.284435e-07  8.779621e-07 -5.172144e-06
#
#                  Emg6          Emg7          Emg8          Emg9         Emg10  \
# 1024695 -2.836591e-06 -4.080693e-05  5.460801e-06  1.269385e-05  1.475595e-05
# 712644  -7.425846e-07 -3.149082e-06  7.737373e-07  7.811206e-06  4.342475e-07
# 4445021 -1.538894e-06 -1.071230e-07 -3.177586e-06  2.782772e-07 -6.706759e-07
# 696525  -3.703062e-07 -3.416118e-06  5.121508e-06  2.559197e-06 -5.195440e-06
# 2734628  2.757880e-07 -8.285247e-08  1.185234e-05 -5.703544e-06  4.347314e-06
#
# ...

# %%
print("The Shape of the Dataset is : ",raw_data.shape)
print("************************************************************************************************************")
print("Column Names of the Dataset are : ",raw_data.columns)
print("************************************************************************************************************")
print(raw_data.info())
print("************************************************************************************************************")
raw_data.describe(include='all')
# Out:
# The Shape of the Dataset is :  (5238693, 16)
# ************************************************************************************************************
# Column Names of the Dataset are :  Index(['Emg1', 'Emg2', 'Emg3', 'Emg4', 'Emg5', 'Emg6', 'Emg7', 'Emg8', 'Emg9',
#        'Emg10', 'Emg11', 'Emg12', 'repetition', 'rerepetition', 'stimulus',
#        'restimulus'],
#       dtype='object')
# ************************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5238693 entries, 0 to 5238692
# Data columns (total 16 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Emg1          float32
#  1   Emg2          float32
#  2   Emg3          float32
#  3   Emg4          float32
#  4   Emg5          float32
#  5   Emg6          float32
#  6   Emg7          float32
#  7   Emg8          float32
#  8   Emg9          float32
#  9   Emg10         float32
# ...

# %%
print("Unique Dependent values and their counts :")
print(raw_data["stimulus"].value_counts())
# Out:
# Unique Dependent values and their counts :
# 0     2035916
# 1       67053
# 38      67007
# 39      66858
# 18      66804
# 8       66570
# 12      66557
# 25      66551
# 7       66495
# 34      66478
# 16      66451
# 31      66445
# 26      66445
# 23      66438
# 29      66433
# 14      66432
# 13      66425
# 27      66392
# 6       66376
# 36      66370
# 20      66350
# 28      66330
# 15      66317
# 30      66311
# 33      66307
# 40      66300
# 10      66294
# 19      66261
# 35      66253
# 22      66243
# 21      66240
# 37      66235
# 24      66230
# 17      66212
# 3       66199
# 32      66169
# 5       66133
# 11      66085
# 4       66067
# 9       66060
# 2       66051
# 44      60927
# 42      60873
# 47      60869
# 45      60866
# 48      60862
# 46      60821
# 41      60818
# 49      60762
# 43      60752
# Name: stimulus, dtype: int64

# %%
count_classes = pd.value_counts(raw_data['stimulus'], sort = True)

count_classes.plot(kind = 'bar', rot=0)

plt.title("stimulus Class Distribution")

plt.xlabel("Class")

plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
print(raw_data.isnull().any())
# Out:
# Emg1            False
# Emg2            False
# Emg3            False
# Emg4            False
# Emg5            False
# Emg6            False
# Emg7            False
# Emg8            False
# Emg9            False
# Emg10           False
# Emg11           False
# Emg12           False
# repetition      False
# rerepetition     True
# stimulus        False
# restimulus       True
# dtype: bool

# %% [markdown]
# # Outlier Detection -- Standard Deviation Method

# %%
raw_data.head()
# Out:
#        Emg1          Emg2          Emg3      Emg4      Emg5          Emg6  \
# 0 -0.000003  3.355261e-06  1.598866e-06 -0.000001 -0.000002  2.749975e-06
# 1 -0.000005  3.355212e-06  1.430441e-06 -0.000003 -0.000003  2.246543e-06
# 2 -0.000003  4.026560e-06  9.263165e-07 -0.000005 -0.000004  1.239568e-06
# 3  0.000002  2.851566e-06  7.578904e-07 -0.000007 -0.000004  1.575385e-06
# 4  0.000004  6.694763e-07  1.764409e-06 -0.000005 -0.000006  7.362596e-07
#
#            Emg7          Emg8          Emg9     Emg10         Emg11     Emg12  \
# 0 -2.347791e-06  1.537436e-07 -2.484787e-07  0.000001 -5.609089e-06  0.000040
# 1 -1.657156e-07  2.503453e-06 -3.561109e-07  0.000002 -3.259393e-06  0.000050
# 2  2.352061e-06  5.524560e-06 -2.445606e-07  0.000002 -7.045269e-08  0.000047
# 3  2.016400e-06  5.188681e-06  1.094450e-06  0.000003  1.439995e-06  0.000032
# 4  8.414949e-07  8.244234e-07  1.154750e-06  0.000003  9.700835e-08  0.000014
#
#    repetition  rerepetition  stimulus  restimulus
# ...

# %%
plt.figure(figsize = (10,5))
sns.distplot(raw_data['Emg1'])
# Out:
# C:\Users\nafem\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Emg1', ylabel='Density'>

# %%
def out_std(df, column):
    global lower,upper
    # calculate the mean and standard deviation of the data frame
    data_mean, data_std = df[column].mean(), df[column].std()
    # calculate the cutoff value
    cut_off = data_std * 3
    # calculate the lower and upper bound value
    lower, upper = data_mean - cut_off, data_mean + cut_off
    print('The lower bound value is', lower)
    print('The upper bound value is', upper)
    # Calculate the number of records below and above lower and above bound value respectively
    df1 = df[df[column] > upper]
    df2 = df[df[column] < lower]
    return print('Total number of outliers are', df1.shape[0]+ df2.shape[0])

# %%
out_std(raw_data,'Emg1')
# Out:
# The lower bound value is -0.00013665686182001702
# The upper bound value is 0.0001366555656327484
# Total number of outliers are 107664

# %%
plt.figure(figsize = (10,5))
sns.distplot(raw_data['Emg1'], kde=False)
plt.axvspan(xmin = lower,xmax= df_2['Emg1'].min(),alpha=0.2, color='red')
plt.axvspan(xmin = upper,xmax= df_2['Emg1'].max(),alpha=0.2, color='red')
# Out:
# C:\Users\nafem\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
out_std(raw_data,'Emg2')
# Out:
# The lower bound value is -7.918173445173315e-05
# The upper bound value is 7.91813274762243e-05
# Total number of outliers are 104985

# %%
#Data Frame without outliers
raw_data = raw_data[(raw_data['Emg1'] < upper) | (raw_data['Emg1'] > lower)]
raw_data = raw_data[(raw_data['Emg2'] < upper) | (raw_data['Emg2'] > lower)]
raw_data = raw_data[(raw_data['Emg3'] < upper) | (raw_data['Emg3'] > lower)]
raw_data = raw_data[(raw_data['Emg4'] < upper) | (raw_data['Emg4'] > lower)]
raw_data = raw_data[(raw_data['Emg5'] < upper) | (raw_data['Emg5'] > lower)]
raw_data = raw_data[(raw_data['Emg6'] < upper) | (raw_data['Emg6'] > lower)]
raw_data = raw_data[(raw_data['Emg7'] < upper) | (raw_data['Emg7'] > lower)]
raw_data = raw_data[(raw_data['Emg8'] < upper) | (raw_data['Emg8'] > lower)]
raw_data = raw_data[(raw_data['Emg9'] < upper) | (raw_data['Emg9'] > lower)]
raw_data = raw_data[(raw_data['Emg10'] < upper) | (raw_data['Emg10'] > lower)]

# %%
raw_data.shape
# Out:
# (5238693, 16)

# %%
print(raw_data.isnull().any())
# Out:
# Emg1            False
# Emg2            False
# Emg3            False
# Emg4            False
# Emg5            False
# Emg6            False
# Emg7            False
# Emg8            False
# Emg9            False
# Emg10           False
# Emg11           False
# Emg12           False
# repetition      False
# rerepetition     True
# stimulus        False
# restimulus       True
# dtype: bool

# %% [markdown]
# # Splitting data for training and testing

# %%
X = raw_data.iloc[:,0:12]
y = raw_data.stimulus

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 39)

# %% [markdown]
# # Machine Learning Models

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree
tree = tree.DecisionTreeClassifier()
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred1 = tree.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = {accuracy_score(y_test, y_pred1)}
print(f"Accuracy is: {accuracy_score(y_test, y_pred1)* 100}")
# Out:
# Accuracy is: 40.21908127882994

# %%
print('\033[1m' +'Classification report : '+ '\033[0m\n', classification_report(y_test, y_pred1))

cm = confusion_matrix(y_pred1, y_test)
print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
sns.heatmap(cm, cmap = 'OrRd',annot = True, fmt='d')
plt.show()
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.41      1.00      0.58    406881
#            1       0.22      0.00      0.00     13394
#            2       0.12      0.00      0.00     13228
#            3       0.28      0.02      0.04     13284
#            4       0.09      0.00      0.01     13249
#            5       0.24      0.02      0.03     13325
#            6       0.40      0.08      0.13     13352
#            7       0.17      0.00      0.01     13182
#            8       0.20      0.02      0.03     13273
#            9       0.24      0.01      0.01     13251
#           10       0.16      0.00      0.01     13305
#           11       0.18      0.01      0.01     13120
#           12       0.16      0.01      0.02     13189
#           13       0.53      0.10      0.17     13481
#           14       0.49      0.07      0.12     13418
#           15       0.38      0.05      0.09     13179
# ...

# %% [markdown]
# # Evaluation -- Decision Tree

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test,y_pred1))
print('MSE:', metrics.mean_squared_error(y_test, y_pred1))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred1)))

# %%
from sklearn.metrics import precision_score
print("Precision Score : ",precision_score(y_test, y_pred1, average='weighted'))


from sklearn.metrics import recall_score
print("Recall Score : ",recall_score(y_test, y_pred1,average='weighted'))


from sklearn.metrics import f1_score
print("f1_score : ",f1_score(y_test, y_pred1,average='weighted'))

# %% [markdown]
# # KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
KNeighborsClassifier = KNeighborsClassifier()
KNeighborsClassifier.fit(X_train, y_train)

# %%
y_pred2 = KNeighborsClassifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = {accuracy_score(y_test, y_pred2)}
print(f"Accuracy is: {accuracy_score(y_test, y_pred2)* 100}")

# %%
print('\033[1m' +'Classification report : '+ '\033[0m\n', classification_report(y_test, y_pred2))

cm = confusion_matrix(y_pred2, y_test)
print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
sns.heatmap(cm, cmap = 'OrRd',annot = True, fmt='d')
plt.show()

# %% [markdown]
# # Evaluation -- KNeighborsClassifier

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test,y_pred2))
print('MSE:', metrics.mean_squared_error(y_test, y_pred2))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred2)))

# %%
from sklearn.metrics import precision_score
print("Precision Score : ",precision_score(y_test, y_pred2, average='weighted'))


from sklearn.metrics import recall_score
print("Recall Score : ",recall_score(y_test, y_pred2,average='weighted'))


from sklearn.metrics import f1_score
print("f1_score : ",f1_score(y_test, y_pred2,average='weighted'))

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
RandomForestClassifier = RandomForestClassifier()
RandomForestClassifier.fit(X_train, y_train)

# %%
y_pred3 = RandomForestClassifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = {accuracy_score(y_test, y_pred3)}
print(f"Accuracy is: {accuracy_score(y_test, y_pred3)* 100}")

# %%
print('\033[1m' +'Classification report : '+ '\033[0m\n', classification_report(y_test, y_pred3))

cm = confusion_matrix(y_pred3, y_test)
print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
sns.heatmap(cm, cmap = 'OrRd',annot = True, fmt='d')
plt.show()

# %% [markdown]
# # Evaluation -- Random Forest

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test,y_pred3))
print('MSE:', metrics.mean_squared_error(y_test, y_pred3))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred3)))

# %%
from sklearn.metrics import precision_score
print("Precision Score : ",precision_score(y_test, y_pred3, average='weighted'))


from sklearn.metrics import recall_score
print("Recall Score : ",recall_score(y_test, y_pred3,average='weighted'))


from sklearn.metrics import f1_score
print("f1_score : ",f1_score(y_test, y_pred3,average='weighted'))

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(X_train, y_train)

# %%
y_pred4 = xgb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = {accuracy_score(y_test, y_pred4)}
print(f"Accuracy is: {accuracy_score(y_test, y_pred4)* 100}")

# %%
print('\033[1m' +'Classification report : '+ '\033[0m\n', classification_report(y_test, y_pred4))

cm = confusion_matrix(y_pred4, y_test)
print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
sns.heatmap(cm, cmap = 'OrRd',annot = True, fmt='d')
plt.show()

# %% [markdown]
# # Evaluation -- XGBoost

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test,y_pred4))
print('MSE:', metrics.mean_squared_error(y_test, y_pred4))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred4)))

# %%
from sklearn.metrics import precision_score
print("Precision Score : ",precision_score(y_test, y_pred4, average='weighted'))


from sklearn.metrics import recall_score
print("Recall Score : ",recall_score(y_test, y_pred4,average='weighted'))


from sklearn.metrics import f1_score
print("f1_score : ",f1_score(y_test, y_pred4,average='weighted'))

# %% [markdown]
# # ExtraTreesClassifier

# %%
from sklearn.ensemble import ExtraTreesClassifier
extratree = ExtraTreesClassifier()
extratree.fit(X_train, y_train)

# %%
y_pred5 = extratree.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = {accuracy_score(y_test, y_pred5)}
print(f"Accuracy is: {accuracy_score(y_test, y_pred5)* 100}")

# %%
print('\033[1m' +'Classification report : '+ '\033[0m\n', classification_report(y_test, y_pred5))

cm = confusion_matrix(y_pred5, y_test)
print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
sns.heatmap(cm, cmap = 'OrRd',annot = True, fmt='d')
plt.show()

# %% [markdown]
# # Evaluation -- ExtraTreesClassifier

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test,y_pred5))
print('MSE:', metrics.mean_squared_error(y_test, y_pred5))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred5)))

# %%
from sklearn.metrics import precision_score
print("Precision Score : ",precision_score(y_test, y_pred5, average='weighted'))


from sklearn.metrics import recall_score
print("Recall Score : ",recall_score(y_test, y_pred5,average='weighted'))


from sklearn.metrics import f1_score
print("f1_score : ",f1_score(y_test, y_pred5,average='weighted'))
