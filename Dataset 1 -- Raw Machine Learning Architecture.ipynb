# %% [markdown]
# # Importing Libraires

# %%
import pandas as pd
from scipy.io import loadmat

# %% [markdown]
# # Loading Exercise 1

# %%
Exercise_1 = loadmat(r"S1_A1_E1.mat")

# %%
print(Exercise_1)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Mon Jul 28 11:54:15 2014', '__version__': '1.0', '__globals__': [], 'emg': array([[0.0684, 0.0024, 0.0024, ..., 0.0488, 0.0024, 0.0342],
#        [0.0586, 0.0024, 0.0024, ..., 0.0415, 0.0024, 0.0293],
#        [0.0562, 0.0024, 0.0024, ..., 0.0391, 0.0024, 0.0244],
#        ...,
#        [0.0024, 0.0024, 0.0024, ..., 0.0342, 0.0024, 0.0073],
#        [0.0024, 0.0024, 0.0024, ..., 0.0366, 0.0024, 0.0073],
#        [0.0024, 0.0024, 0.0024, ..., 0.0391, 0.0024, 0.0024]]), 'stimulus': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'glove': array([[146., 121., 113., ..., 131., 135., 115.],
#        [146., 121., 113., ..., 131., 135., 115.],
#        [146., 121., 113., ..., 131., 135., 115.],
#        ...,
#        [161., 128., 122., ..., 155., 131., 116.],
#        [161., 128., 122., ..., 155., 131., 116.],
# ...

# %%
print(Exercise_1.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'emg', 'stimulus', 'glove', 'subject', 'exercise', 'repetition', 'restimulus', 'rerepetition'])

# %%
emg_1 = Exercise_1['emg']
stimulus_1 = Exercise_1['stimulus']
restimulus_1 = Exercise_1['restimulus']

# %% [markdown]
# # DataFramae

# %% [markdown]
# ### Convert the dictionary into DataFrame

# %%
# Custom Column Names

# %%
df_1= pd.DataFrame(emg_1, 
                  columns = ['Emg1','Emg2','Emg3','Emg4','Emg5','Emg6','Emg7','Emg8','Emg9','Emg10'])

# %%
df_1
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 0       0.0684  0.0024  0.0024  0.0024  0.0024  0.0098  0.0024  0.0488
# 1       0.0586  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0415
# 2       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0391
# 3       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0342
# 4       0.0488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 101009  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0024  0.0366
# 101010  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342
# 101011  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342
# 101012  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 101013  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0391
#
#           Emg9   Emg10
# 0       0.0024  0.0342
# 1       0.0024  0.0293
# 2       0.0024  0.0244
# ...

# %%
stimulus_1 = pd.DataFrame(stimulus_1)
restimulus_1 = pd.DataFrame(restimulus_1)

# %% [markdown]
# ### Adding new column to existing DataFrame

# %%
df_1['stimulus'] = stimulus_1
df_1['restimulus'] = restimulus_1

# %% [markdown]
# # Final Output of Exercise 1 DataFrame

# %%
df_1
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 0       0.0684  0.0024  0.0024  0.0024  0.0024  0.0098  0.0024  0.0488
# 1       0.0586  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0415
# 2       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0391
# 3       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0342
# 4       0.0488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 101009  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0024  0.0366
# 101010  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342
# 101011  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342
# 101012  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 101013  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0391
#
#           Emg9   Emg10  stimulus  restimulus
# 0       0.0024  0.0342         0           0
# ...

# %%
print(df_1.describe(include = 'all'))
print("************************************************************************************************************")
print(df_1.info())
print("************************************************************************************************************")
print("Shape of the Dataset is", df_1.shape)
# Out:
#                 Emg1           Emg2           Emg3           Emg4  \
# count  101014.000000  101014.000000  101014.000000  101014.000000
# mean        0.039693       0.086158       0.041308       0.012502
# std         0.127180       0.231539       0.101912       0.031334
# min         0.002400       0.000000       0.002400       0.000000
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.002400       0.002400       0.002400       0.002400
# 75%         0.024400       0.002400       0.012200       0.002400
# max         2.399900       2.480500       1.340300       0.446800
#
#                 Emg5           Emg6           Emg7           Emg8  \
# count  101014.000000  101014.000000  101014.000000  101014.000000
# mean        0.003868       0.005367       0.167648       0.116476
# std         0.009796       0.021238       0.403823       0.174862
# min         0.002400       0.000000       0.002400       0.002400
# ...

# %% [markdown]
# #  Loading Exercise 2

# %%
Exercise_2 = loadmat(r"S1_A1_E2.mat")

# %%
print(Exercise_2)
print("************************************************************************************************************")
print(Exercise_2.keys())
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Mon Jul 28 11:54:17 2014', '__version__': '1.0', '__globals__': [], 'emg': array([[0.0024, 0.0024, 0.0024, ..., 0.0366, 0.0024, 0.0024],
#        [0.0024, 0.0024, 0.0024, ..., 0.0366, 0.0024, 0.0024],
#        [0.0024, 0.0024, 0.0024, ..., 0.0366, 0.0024, 0.0024],
#        ...,
#        [0.022 , 0.0024, 0.0024, ..., 0.0903, 0.0024, 0.0415],
#        [0.0342, 0.0024, 0.0049, ..., 0.1172, 0.0024, 0.0415],
#        [0.0415, 0.0024, 0.0024, ..., 0.1318, 0.0024, 0.0439]]), 'stimulus': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'glove': array([[160., 124., 118., ..., 159., 132., 112.],
#        [160., 124., 118., ..., 159., 132., 112.],
#        [160., 124., 118., ..., 159., 132., 112.],
#        ...,
#        [139., 141., 119., ..., 145., 131., 118.],
#        [139., 141., 119., ..., 145., 131., 118.],
# ...

# %%
emg_2 = Exercise_2['emg']
stimulus_2 = Exercise_2['stimulus']
restimulus_2 = Exercise_2['restimulus']

# %% [markdown]
# # DataFramae

# %% [markdown]
# ### Convert the dictionary into DataFrame

# %%
df_2= pd.DataFrame(emg_2, 
                  columns = ['Emg1','Emg2','Emg3','Emg4','Emg5','Emg6','Emg7','Emg8','Emg9','Emg10'])

# %%
df_2
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 0       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 1       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 2       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 3       0.0195  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0537
# 4       0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0659
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 142971  0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0146  0.1025
# 142972  0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0146  0.1025
# 142973  0.0220  0.0024  0.0024  0.0024  0.0024  0.0024  0.0073  0.0903
# 142974  0.0342  0.0024  0.0049  0.0024  0.0024  0.0024  0.0171  0.1172
# 142975  0.0415  0.0024  0.0024  0.0024  0.0024  0.0024  0.0220  0.1318
#
#           Emg9   Emg10
# 0       0.0024  0.0024
# 1       0.0024  0.0024
# 2       0.0024  0.0024
# ...

# %%
stimulus_2 = pd.DataFrame(stimulus_2)
restimulus_2 = pd.DataFrame(restimulus_2)

# %% [markdown]
# ### Adding new column to existing DataFrame

# %%
df_2['stimulus'] = stimulus_2
df_2['restimulus'] = restimulus_2

# %%
df_2
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 0       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 1       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 2       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 3       0.0195  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0537
# 4       0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0659
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 142971  0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0146  0.1025
# 142972  0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0146  0.1025
# 142973  0.0220  0.0024  0.0024  0.0024  0.0024  0.0024  0.0073  0.0903
# 142974  0.0342  0.0024  0.0049  0.0024  0.0024  0.0024  0.0171  0.1172
# 142975  0.0415  0.0024  0.0024  0.0024  0.0024  0.0024  0.0220  0.1318
#
#           Emg9   Emg10  stimulus  restimulus
# 0       0.0024  0.0024         0           0
# ...

# %% [markdown]
# # Replacing Values of Stimulus Exercise 2

# %% [markdown]
# https://dataindependent.com/pandas/pandas-replace-values-pd-dataframe-replace/

# %%
df_2 = df_2.replace(to_replace={'stimulus': {1: 13}}, value=None)
df_2 = df_2.replace(to_replace={'stimulus': {2: 14}}, value=None)
df_2 = df_2.replace(to_replace={'stimulus': {3: 15}}, value=None)
df_2 = df_2.replace(to_replace={'stimulus': {4: 16}}, value=None)
df_2 = df_2.replace(to_replace={'stimulus': {5: 17}}, value=None)
df_2 = df_2.replace(to_replace={'stimulus': {6: 18}}, value=None)
df_2 = df_2.replace(to_replace={'stimulus': {7: 19}}, value=None)
df_2 = df_2.replace(to_replace={'stimulus': {8: 20}}, value=None)
df_2 = df_2.replace(to_replace={'stimulus': {9: 21}}, value=None)
df_2 = df_2.replace(to_replace={'stimulus': {10: 22}}, value=None)
df_2 = df_2.replace(to_replace={'stimulus': {11: 23}}, value=None)
df_2 = df_2.replace(to_replace={'stimulus': {12: 24}}, value=None)
df_2 = df_2.replace(to_replace={'stimulus': {13: 25}}, value=None)
df_2 = df_2.replace(to_replace={'stimulus': {14: 26}}, value=None)
df_2 = df_2.replace(to_replace={'stimulus': {15: 27}}, value=None)
df_2 = df_2.replace(to_replace={'stimulus': {16: 28}}, value=None)
df_2 = df_2.replace(to_replace={'stimulus': {17: 29}}, value=None)

# %%
df_2.describe()
# Out:
#                 Emg1           Emg2           Emg3           Emg4  \
# count  142976.000000  142976.000000  142976.000000  142976.000000
# mean        0.117857       0.143417       0.066564       0.041402
# std         0.272271       0.397495       0.239760       0.193168
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.017100       0.002400       0.002400       0.002400
# 75%         0.105000       0.009800       0.004900       0.002400
# max         4.226100       4.663100       4.655800       4.663100
#
#                 Emg5           Emg6           Emg7           Emg8  \
# count  142976.000000  142976.000000  142976.000000  142976.000000
# mean        0.009957       0.014334       0.265964       0.227472
# std         0.030656       0.049708       0.599680       0.430314
# min         0.002400       0.000000       0.002400       0.002400
# ...

# %% [markdown]
# # Replacing Values of Restimulus Exercise 2

# %%
df_2 = df_2.replace(to_replace={'restimulus': {1: 13}}, value=None)
df_2 = df_2.replace(to_replace={'restimulus': {2: 14}}, value=None)
df_2 = df_2.replace(to_replace={'restimulus': {3: 15}}, value=None)
df_2 = df_2.replace(to_replace={'restimulus': {4: 16}}, value=None)
df_2 = df_2.replace(to_replace={'restimulus': {5: 17}}, value=None)
df_2 = df_2.replace(to_replace={'restimulus': {6: 18}}, value=None)
df_2 = df_2.replace(to_replace={'restimulus': {7: 19}}, value=None)
df_2 = df_2.replace(to_replace={'restimulus': {8: 20}}, value=None)
df_2 = df_2.replace(to_replace={'restimulus': {9: 21}}, value=None)
df_2 = df_2.replace(to_replace={'restimulus': {10: 22}}, value=None)
df_2 = df_2.replace(to_replace={'restimulus': {11: 23}}, value=None)
df_2 = df_2.replace(to_replace={'restimulus': {12: 24}}, value=None)
df_2 = df_2.replace(to_replace={'restimulus': {13: 25}}, value=None)
df_2 = df_2.replace(to_replace={'restimulus': {14: 26}}, value=None)
df_2 = df_2.replace(to_replace={'restimulus': {15: 27}}, value=None)
df_2 = df_2.replace(to_replace={'restimulus': {16: 28}}, value=None)
df_2 = df_2.replace(to_replace={'restimulus': {17: 29}}, value=None)

# %%
df_2.describe()
# Out:
#                 Emg1           Emg2           Emg3           Emg4  \
# count  142976.000000  142976.000000  142976.000000  142976.000000
# mean        0.117857       0.143417       0.066564       0.041402
# std         0.272271       0.397495       0.239760       0.193168
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.017100       0.002400       0.002400       0.002400
# 75%         0.105000       0.009800       0.004900       0.002400
# max         4.226100       4.663100       4.655800       4.663100
#
#                 Emg5           Emg6           Emg7           Emg8  \
# count  142976.000000  142976.000000  142976.000000  142976.000000
# mean        0.009957       0.014334       0.265964       0.227472
# std         0.030656       0.049708       0.599680       0.430314
# min         0.002400       0.000000       0.002400       0.002400
# ...

# %% [markdown]
# # Final Output of Exercise 2 DataFrame

# %%
df_2
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 0       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 1       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 2       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 3       0.0195  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0537
# 4       0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0659
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 142971  0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0146  0.1025
# 142972  0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0146  0.1025
# 142973  0.0220  0.0024  0.0024  0.0024  0.0024  0.0024  0.0073  0.0903
# 142974  0.0342  0.0024  0.0049  0.0024  0.0024  0.0024  0.0171  0.1172
# 142975  0.0415  0.0024  0.0024  0.0024  0.0024  0.0024  0.0220  0.1318
#
#           Emg9   Emg10  stimulus  restimulus
# 0       0.0024  0.0024         0           0
# ...

# %%
print(df_2.describe(include = 'all'))
print("************************************************************************************************************")
print(df_2.info())
print("************************************************************************************************************")
print("Shape of the Dataset is", df_2.shape)
# Out:
#                 Emg1           Emg2           Emg3           Emg4  \
# count  142976.000000  142976.000000  142976.000000  142976.000000
# mean        0.117857       0.143417       0.066564       0.041402
# std         0.272271       0.397495       0.239760       0.193168
# min         0.002400       0.000000       0.002400       0.002400
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.017100       0.002400       0.002400       0.002400
# 75%         0.105000       0.009800       0.004900       0.002400
# max         4.226100       4.663100       4.655800       4.663100
#
#                 Emg5           Emg6           Emg7           Emg8  \
# count  142976.000000  142976.000000  142976.000000  142976.000000
# mean        0.009957       0.014334       0.265964       0.227472
# std         0.030656       0.049708       0.599680       0.430314
# min         0.002400       0.000000       0.002400       0.002400
# ...

# %% [markdown]
# #  Loading Exercise 3

# %%
Exercise_3 = loadmat(r"S1_A1_E3.mat")

# %%
print(Exercise_3)
print("************************************************************************************************************")
print(Exercise_3.keys())
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Mon Jul 28 11:54:18 2014', '__version__': '1.0', '__globals__': [], 'emg': array([[0.0024, 0.0024, 0.0024, ..., 0.0732, 0.0024, 0.0903],
#        [0.0024, 0.0024, 0.0024, ..., 0.0757, 0.0024, 0.0928],
#        [0.0024, 0.0024, 0.0024, ..., 0.0879, 0.0024, 0.0903],
#        ...,
#        [0.0024, 0.0024, 0.0024, ..., 0.0513, 0.127 , 0.0024],
#        [0.0024, 0.0024, 0.0024, ..., 0.0488, 0.1294, 0.0024],
#        [0.0024, 0.0024, 0.0024, ..., 0.0439, 0.1294, 0.0024]]), 'stimulus': array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=uint8), 'glove': array([[152., 137., 111., ..., 139., 134., 108.],
#        [152., 137., 111., ..., 139., 134., 108.],
#        [152., 137., 111., ..., 139., 134., 108.],
#        ...,
#        [152., 131., 114., ..., 124., 133., 120.],
#        [152., 131., 114., ..., 124., 133., 120.],
# ...

# %%
emg_3 = Exercise_3['emg']
stimulus_3 = Exercise_3['stimulus']
restimulus_3 = Exercise_3['restimulus']

# %% [markdown]
# # DataFramae

# %%
df_3= pd.DataFrame(emg_3, 
                  columns = ['Emg1','Emg2','Emg3','Emg4','Emg5','Emg6','Emg7','Emg8','Emg9','Emg10'])

# %%
df_3
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 0       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0317  0.0732
# 1       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366  0.0757
# 2       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0415  0.0879
# 3       0.0024  0.0024  0.0049  0.0024  0.0024  0.0024  0.0366  0.0952
# 4       0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0293  0.0952
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 227488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0562
# 227489  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0513
# 227490  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0513
# 227491  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0488
# 227492  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0439
#
#           Emg9   Emg10
# 0       0.0024  0.0903
# 1       0.0024  0.0928
# 2       0.0024  0.0903
# ...

# %%
stimulus_3 = pd.DataFrame(stimulus_3)
restimulus_3 = pd.DataFrame(restimulus_3)

# %% [markdown]
# # Adding new column to existing DataFrame

# %%
df_3['stimulus'] = stimulus_3
df_3['restimulus'] = restimulus_3

# %%
df_3.describe()
# Out:
#                 Emg1           Emg2           Emg3           Emg4  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.177020       0.125848       0.195590       0.060284
# std         0.332936       0.303522       0.430584       0.183509
# min         0.002400       0.000000       0.002400       0.000000
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.034200       0.002400       0.002400       0.002400
# 75%         0.195300       0.097700       0.180700       0.034200
# max         4.665500       4.660600       4.658200       4.619100
#
#                 Emg5           Emg6           Emg7           Emg8  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.018392       0.018891       0.218081       0.289072
# std         0.038278       0.043190       0.410667       0.346111
# min         0.002400       0.000000       0.002400       0.002400
# ...

# %% [markdown]
# # Replacing Values of Stimulus Exercise 3

# %%
df_3 = df_3.replace(to_replace={'stimulus': {1: 30}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {2: 31}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {3: 32}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {4: 33}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {5: 34}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {6: 35}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {7: 36}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {8: 37}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {9: 38}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {10: 39}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {11: 40}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {12: 41}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {13: 42}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {14: 43}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {15: 44}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {16: 45}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {17: 46}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {18: 47}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {18: 48}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {19: 49}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {20: 50}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {21: 51}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {22: 52}}, value=None)
df_3 = df_3.replace(to_replace={'stimulus': {23: 53}}, value=None)

# %% [markdown]
# # Replacing Values of restimulus Exercise 3

# %%
df_3 = df_3.replace(to_replace={'restimulus': {1: 30}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {2: 31}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {3: 32}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {4: 33}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {5: 34}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {6: 35}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {7: 36}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {8: 37}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {9: 38}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {10: 39}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {11: 40}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {12: 41}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {13: 42}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {14: 43}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {15: 44}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {16: 45}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {17: 46}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {18: 47}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {18: 48}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {19: 49}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {20: 50}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {21: 51}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {22: 52}}, value=None)
df_3 = df_3.replace(to_replace={'restimulus': {23: 53}}, value=None)

# %% [markdown]
# # Final Output of Exercise 3 DataFrame

# %%
df_3
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 0       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0317  0.0732
# 1       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366  0.0757
# 2       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0415  0.0879
# 3       0.0024  0.0024  0.0049  0.0024  0.0024  0.0024  0.0366  0.0952
# 4       0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0293  0.0952
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 227488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0562
# 227489  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0513
# 227490  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0513
# 227491  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0488
# 227492  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0439
#
#           Emg9   Emg10  stimulus  restimulus
# 0       0.0024  0.0903         0           0
# ...

# %%
print(df_3.describe(include = 'all'))
print("************************************************************************************************************")
print(df_3.info())
print("************************************************************************************************************")
print("Shape of the Dataset is", df_3.shape)
# Out:
#                 Emg1           Emg2           Emg3           Emg4  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.177020       0.125848       0.195590       0.060284
# std         0.332936       0.303522       0.430584       0.183509
# min         0.002400       0.000000       0.002400       0.000000
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.034200       0.002400       0.002400       0.002400
# 75%         0.195300       0.097700       0.180700       0.034200
# max         4.665500       4.660600       4.658200       4.619100
#
#                 Emg5           Emg6           Emg7           Emg8  \
# count  227493.000000  227493.000000  227493.000000  227493.000000
# mean        0.018392       0.018891       0.218081       0.289072
# std         0.038278       0.043190       0.410667       0.346111
# min         0.002400       0.000000       0.002400       0.002400
# ...

# %% [markdown]
# # Add a row from one dataframe to other dataframe

# %% [markdown]
# https://appdividend.com/2020/01/22/python-pandas-how-to-add-rows-in-dataframe/#:~:text=Python%20Pandas%20dataframe%20append(),or%20add%20a%20new%20row.

# %%
df_1_2 = df_1.append(df_2, ignore_index=True)

# %%
df_1_2
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 0       0.0684  0.0024  0.0024  0.0024  0.0024  0.0098  0.0024  0.0488
# 1       0.0586  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0415
# 2       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0391
# 3       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0342
# 4       0.0488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 243985  0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0146  0.1025
# 243986  0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0146  0.1025
# 243987  0.0220  0.0024  0.0024  0.0024  0.0024  0.0024  0.0073  0.0903
# 243988  0.0342  0.0024  0.0049  0.0024  0.0024  0.0024  0.0171  0.1172
# 243989  0.0415  0.0024  0.0024  0.0024  0.0024  0.0024  0.0220  0.1318
#
#           Emg9   Emg10  stimulus  restimulus
# 0       0.0024  0.0342         0           0
# ...

# %%
df_1_2_3 = df_1_2.append(df_3, ignore_index=True)

# %% [markdown]
# # Final Output

# %%
df_1_2_3
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 0       0.0684  0.0024  0.0024  0.0024  0.0024  0.0098  0.0024  0.0488
# 1       0.0586  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0415
# 2       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0391
# 3       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0342
# 4       0.0488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 471478  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0562
# 471479  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0513
# 471480  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0513
# 471481  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0488
# 471482  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0439
#
#           Emg9   Emg10  stimulus  restimulus
# 0       0.0024  0.0342         0           0
# ...

# %%
print(df_1_2_3.describe(include = 'all'))
print("************************************************************************************************************")
print(df_1_2_3.info())
print("************************************************************************************************************")
print("Shape of the Dataset is", df_1_2_3.shape)
# Out:
#                 Emg1           Emg2           Emg3           Emg4  \
# count  471483.000000  471483.000000  471483.000000  471483.000000
# mean        0.129657       0.122672       0.123409       0.044321
# std         0.286859       0.322911       0.337717       0.167680
# min         0.002400       0.000000       0.002400       0.000000
# 25%         0.002400       0.002400       0.002400       0.002400
# 50%         0.017100       0.002400       0.002400       0.002400
# 75%         0.114700       0.046400       0.058600       0.007300
# max         4.665500       4.663100       4.658200       4.663100
#
#                 Emg5           Emg6           Emg7           Emg8  \
# count  471483.000000  471483.000000  471483.000000  471483.000000
# mean        0.012722       0.014612       0.221796       0.233414
# std         0.032359       0.042109       0.476014       0.353467
# min         0.002400       0.000000       0.002400       0.002400
# ...

# %% [markdown]
# # Compersion

# %%
df_1
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 0       0.0684  0.0024  0.0024  0.0024  0.0024  0.0098  0.0024  0.0488
# 1       0.0586  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0415
# 2       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0391
# 3       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0342
# 4       0.0488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 101009  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0024  0.0366
# 101010  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342
# 101011  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0342
# 101012  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 101013  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0391
#
#           Emg9   Emg10  stimulus  restimulus
# 0       0.0024  0.0342         0           0
# ...

# %%
df_2
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 0       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 1       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 2       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# 3       0.0195  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0537
# 4       0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0659
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 142971  0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0146  0.1025
# 142972  0.0293  0.0024  0.0024  0.0024  0.0024  0.0024  0.0146  0.1025
# 142973  0.0220  0.0024  0.0024  0.0024  0.0024  0.0024  0.0073  0.0903
# 142974  0.0342  0.0024  0.0049  0.0024  0.0024  0.0024  0.0171  0.1172
# 142975  0.0415  0.0024  0.0024  0.0024  0.0024  0.0024  0.0220  0.1318
#
#           Emg9   Emg10  stimulus  restimulus
# 0       0.0024  0.0024         0           0
# ...

# %%
df_3
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 0       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0317  0.0732
# 1       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366  0.0757
# 2       0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0415  0.0879
# 3       0.0024  0.0024  0.0049  0.0024  0.0024  0.0024  0.0366  0.0952
# 4       0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0293  0.0952
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 227488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0562
# 227489  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0513
# 227490  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0513
# 227491  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0488
# 227492  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0439
#
#           Emg9   Emg10  stimulus  restimulus
# 0       0.0024  0.0903         0           0
# ...

# %%
df_1_2_3
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 0       0.0684  0.0024  0.0024  0.0024  0.0024  0.0098  0.0024  0.0488
# 1       0.0586  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0415
# 2       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0391
# 3       0.0562  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0342
# 4       0.0488  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0366
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 471478  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0562
# 471479  0.0024  0.0024  0.0024  0.0024  0.0024  0.0049  0.0024  0.0513
# 471480  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0513
# 471481  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0488
# 471482  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0439
#
#           Emg9   Emg10  stimulus  restimulus
# 0       0.0024  0.0342         0           0
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, classification_report

# %%
raw_data = df_1_2_3
raw_data.sample(5)
# Out:
#           Emg1    Emg2    Emg3    Emg4    Emg5    Emg6    Emg7    Emg8  \
# 125115  0.1685  1.0181  0.3296  0.1147  0.0024  0.0269  1.6309  0.9058
# 58198   0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.3247  0.1001
# 83989   0.0024  0.0024  0.0024  0.0024  0.0024  0.0024  0.0952  0.0635
# 245442  0.0830  0.0317  0.4858  0.1147  0.0049  0.0342  0.2710  0.1587
# 411676  0.0586  0.0024  0.0024  0.0024  0.0024  0.0024  0.0586  0.1343
#
#           Emg9   Emg10  stimulus  restimulus
# 125115  0.3833  0.4980        27          27
# 58198   0.0024  0.0757         0           0
# 83989   0.0024  0.0024         0           0
# 245442  0.3369  0.0781        30          30
# 411676  0.0024  0.0073         0           0

# %%
print("The Shape of the Dataset is : ",raw_data.shape)
print("************************************************************************************************************")
print("Column Names of the Dataset are : ",raw_data.columns)
print("************************************************************************************************************")
print(raw_data.info())
print("************************************************************************************************************")
raw_data.describe(include='all')
# Out:
# The Shape of the Dataset is :  (471483, 12)
# ************************************************************************************************************
# Column Names of the Dataset are :  Index(['Emg1', 'Emg2', 'Emg3', 'Emg4', 'Emg5', 'Emg6', 'Emg7', 'Emg8', 'Emg9',
#        'Emg10', 'stimulus', 'restimulus'],
#       dtype='object')
# ************************************************************************************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 471483 entries, 0 to 471482
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Emg1        471483 non-null  float64
#  1   Emg2        471483 non-null  float64
#  2   Emg3        471483 non-null  float64
#  3   Emg4        471483 non-null  float64
#  4   Emg5        471483 non-null  float64
#  5   Emg6        471483 non-null  float64
#  6   Emg7        471483 non-null  float64
# ...

# %%
print("Unique Dependent values and their counts :")
print(raw_data["stimulus"].value_counts())
# Out:
# Unique Dependent values and their counts :
# 0     202625
# 27     10351
# 26     10346
# 25     10339
# 29     10328
# 28     10324
# 47      5210
# 50      5202
# 43      5191
# 38      5190
# 41      5189
# 49      5189
# 31      5188
# 42      5186
# 51      5185
# 46      5184
# 40      5182
# 39      5182
# 37      5182
# 20      5177
# 36      5177
# 33      5174
# 2       5174
# 4       5173
# 12      5173
# 5       5173
# 8       5172
# 7       5171
# 24      5170
# 6       5170
# 19      5170
# 18      5167
# 21      5167
# 11      5166
# 53      5166
# 23      5166
# 45      5165
# 30      5162
# 44      5161
# 52      5161
# 22      5158
# 3       5158
# 34      5153
# 1       5149
# 10      5137
# 9       5135
# 32      5133
# 35      5132
# Name: stimulus, dtype: int64

# %%
count_classes = pd.value_counts(raw_data['stimulus'], sort = True)

count_classes.plot(kind = 'bar', rot=0)

plt.title("stimulus Class Distribution")

plt.xlabel("Class")

plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
print(raw_data.isnull().any())
# Out:
# Emg1          False
# Emg2          False
# Emg3          False
# Emg4          False
# Emg5          False
# Emg6          False
# Emg7          False
# Emg8          False
# Emg9          False
# Emg10         False
# stimulus      False
# restimulus    False
# dtype: bool

# %% [markdown]
# # Splitting data for training and testing

# %%
X = raw_data.iloc[:,0:10]
y = raw_data.stimulus

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 39)

# %% [markdown]
# # Machine Learning Models

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree
tree = tree.DecisionTreeClassifier()
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred1 = tree.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = {accuracy_score(y_test, y_pred1)}
print(f"Accuracy is: {accuracy_score(y_test, y_pred1)* 100}")
# Out:
# Accuracy is: 66.6037455725466

# %%
print('\033[1m' +'Classification report : '+ '\033[0m\n', classification_report(y_test, y_pred1))

cm = confusion_matrix(y_pred1, y_test)
print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
sns.heatmap(cm, cmap = 'OrRd',annot = True, fmt='d')
plt.show()
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.72      0.79      0.75     20131
#            1       0.67      0.58      0.62       546
#            2       0.75      0.43      0.54       550
#            3       0.68      0.60      0.64       544
#            4       0.61      0.48      0.54       540
#            5       0.68      0.67      0.67       495
#            6       0.53      0.38      0.45       490
#            7       0.51      0.48      0.49       497
#            8       0.59      0.52      0.55       511
#            9       0.46      0.48      0.47       497
#           10       0.60      0.45      0.51       536
#           11       0.43      0.38      0.40       513
#           12       0.38      0.28      0.32       548
#           18       0.63      0.64      0.64       514
#           19       0.53      0.50      0.51       551
#           20       0.59      0.43      0.50       510
# ...

# %% [markdown]
# # Evaluation -- Decision Tree

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test,y_pred1))
print('MSE:', metrics.mean_squared_error(y_test, y_pred1))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred1)))
# Out:
# MAE: 6.424802222740674
# MSE: 190.75100214214513
# RMSE: 13.811263596867056

# %%
from sklearn.metrics import precision_score
print("Precision Score : ",precision_score(y_test, y_pred1, average='weighted'))


from sklearn.metrics import recall_score
print("Recall Score : ",recall_score(y_test, y_pred1,average='weighted'))


from sklearn.metrics import f1_score
print("f1_score : ",f1_score(y_test, y_pred1,average='weighted'))
# Out:
# Precision Score :  0.6605660767490226
# Recall Score :  0.666037455725466
# f1_score :  0.6609931910413789

# %% [markdown]
# # KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
KNeighborsClassifier = KNeighborsClassifier()
KNeighborsClassifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred2 = KNeighborsClassifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = {accuracy_score(y_test, y_pred2)}
print(f"Accuracy is: {accuracy_score(y_test, y_pred2)* 100}")
# Out:
# Accuracy is: 73.5434473689792

# %%
print('\033[1m' +'Classification report : '+ '\033[0m\n', classification_report(y_test, y_pred2))

cm = confusion_matrix(y_pred2, y_test)
print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
sns.heatmap(cm, cmap = 'OrRd',annot = True, fmt='d')
plt.show()
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.70      0.93      0.80     20131
#            1       0.74      0.62      0.67       546
#            2       0.72      0.48      0.58       550
#            3       0.77      0.62      0.69       544
#            4       0.77      0.51      0.61       540
#            5       0.73      0.66      0.69       495
#            6       0.76      0.41      0.53       490
#            7       0.65      0.55      0.60       497
#            8       0.72      0.54      0.62       511
#            9       0.62      0.46      0.53       497
#           10       0.72      0.43      0.54       536
#           11       0.64      0.37      0.47       513
#           12       0.62      0.26      0.37       548
#           18       0.78      0.64      0.70       514
#           19       0.75      0.50      0.60       551
#           20       0.76      0.44      0.56       510
# ...

# %% [markdown]
# # Evaluation -- KNeighborsClassifier

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test,y_pred2))
print('MSE:', metrics.mean_squared_error(y_test, y_pred2))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred2)))
# Out:
# MAE: 5.301448599121932
# MSE: 158.49880167129737
# RMSE: 12.589630720211668

# %%
from sklearn.metrics import precision_score
print("Precision Score : ",precision_score(y_test, y_pred2, average='weighted'))


from sklearn.metrics import recall_score
print("Recall Score : ",recall_score(y_test, y_pred2,average='weighted'))


from sklearn.metrics import f1_score
print("f1_score : ",f1_score(y_test, y_pred2,average='weighted'))
# Out:
# Precision Score :  0.7449510569714555
# Recall Score :  0.735434473689792
# f1_score :  0.7231155406270368

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
RandomForestClassifier = RandomForestClassifier()
RandomForestClassifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = RandomForestClassifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = {accuracy_score(y_test, y_pred3)}
print(f"Accuracy is: {accuracy_score(y_test, y_pred3)* 100}")
# Out:
# Accuracy is: 76.27521262380964

# %%
print('\033[1m' +'Classification report : '+ '\033[0m\n', classification_report(y_test, y_pred3))

cm = confusion_matrix(y_pred3, y_test)
print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
sns.heatmap(cm, cmap = 'OrRd',annot = True, fmt='d')
plt.show()
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.71      0.91      0.80     20131
#            1       0.79      0.67      0.72       546
#            2       0.84      0.46      0.59       550
#            3       0.81      0.68      0.74       544
#            4       0.78      0.56      0.65       540
#            5       0.82      0.73      0.77       495
#            6       0.82      0.44      0.58       490
#            7       0.66      0.56      0.61       497
#            8       0.74      0.60      0.66       511
#            9       0.64      0.51      0.57       497
#           10       0.71      0.46      0.56       536
#           11       0.61      0.42      0.49       513
#           12       0.55      0.31      0.39       548
#           18       0.84      0.68      0.75       514
#           19       0.74      0.53      0.62       551
#           20       0.76      0.48      0.59       510
# ...

# %% [markdown]
# # Evaluation -- Random Forest

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test,y_pred3))
print('MSE:', metrics.mean_squared_error(y_test, y_pred3))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred3)))
# Out:
# MAE: 4.855055250376466
# MSE: 144.5074762985429
# RMSE: 12.02112624917245

# %%
from sklearn.metrics import precision_score
print("Precision Score : ",precision_score(y_test, y_pred3, average='weighted'))


from sklearn.metrics import recall_score
print("Recall Score : ",recall_score(y_test, y_pred3,average='weighted'))


from sklearn.metrics import f1_score
print("f1_score : ",f1_score(y_test, y_pred3,average='weighted'))
# Out:
# Precision Score :  0.7721570290593905
# Recall Score :  0.7627521262380963
# f1_score :  0.7548466420036913

# %% [markdown]
# # ExtraTreesClassifier

# %%
from sklearn.ensemble import ExtraTreesClassifier
extratree = ExtraTreesClassifier()
extratree.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier()

# %%
y_pred5 = extratree.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = {accuracy_score(y_test, y_pred5)}
print(f"Accuracy is: {accuracy_score(y_test, y_pred5)* 100}")
# Out:
# Accuracy is: 76.25612420199792

# %%
print('\033[1m' +'Classification report : '+ '\033[0m\n', classification_report(y_test, y_pred5))

cm = confusion_matrix(y_pred5, y_test)
print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
sns.heatmap(cm, cmap = 'OrRd',annot = True, fmt='d')
plt.show()
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.71      0.92      0.80     20131
#            1       0.79      0.66      0.72       546
#            2       0.86      0.45      0.59       550
#            3       0.80      0.66      0.72       544
#            4       0.82      0.54      0.65       540
#            5       0.79      0.73      0.76       495
#            6       0.83      0.44      0.58       490
#            7       0.67      0.57      0.62       497
#            8       0.74      0.59      0.66       511
#            9       0.65      0.49      0.56       497
#           10       0.72      0.46      0.56       536
#           11       0.60      0.42      0.50       513
#           12       0.56      0.30      0.39       548
#           18       0.84      0.68      0.76       514
#           19       0.75      0.52      0.61       551
#           20       0.77      0.48      0.60       510
# ...

# %% [markdown]
# # Evaluation -- ExtraTreesClassifier

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test,y_pred5))
print('MSE:', metrics.mean_squared_error(y_test, y_pred5))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred5)))
# Out:
# MAE: 4.936456764724596
# MSE: 148.1295255466712
# RMSE: 12.170847363543395

# %%
from sklearn.metrics import precision_score
print("Precision Score : ",precision_score(y_test, y_pred5, average='weighted'))


from sklearn.metrics import recall_score
print("Recall Score : ",recall_score(y_test, y_pred5,average='weighted'))


from sklearn.metrics import f1_score
print("f1_score : ",f1_score(y_test, y_pred5,average='weighted'))
# Out:
# Precision Score :  0.7745902885947537
# Recall Score :  0.7625612420199792
# f1_score :  0.7546461744966093

# %% [markdown]
# # XGBoost

# %% [raw]
# from xgboost import XGBClassifier
# xgb = XGBClassifier()
# xgb.fit(X_train, y_train)

# %% [raw]
# y_pred4 = xgb.predict(X_test)

# %% [raw]
# from sklearn.metrics import accuracy_score
# accuracy = {accuracy_score(y_test, y_pred4)}
# print(f"Accuracy is: {accuracy_score(y_test, y_pred4)* 100}")

# %% [raw]
# print('\033[1m' +'Classification report : '+ '\033[0m\n', classification_report(y_test, y_pred4))
#
# cm = confusion_matrix(y_pred4, y_test)
# print('\033[1m' +'Confusion Matrix : '+ '\033[0m')
# sns.heatmap(cm, cmap = 'OrRd',annot = True, fmt='d')
# plt.show()

# %% [markdown]
# # Evaluation -- XGBoost

# %% [raw]
# from sklearn import metrics
#
# print('MAE:', metrics.mean_absolute_error(y_test,y_pred4))
# print('MSE:', metrics.mean_squared_error(y_test, y_pred4))
# print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred4)))

# %% [raw]
# from sklearn.metrics import precision_score
# print("Precision Score : ",precision_score(y_test, y_pred4, average='weighted'))
#
#
# from sklearn.metrics import recall_score
# print("Recall Score : ",recall_score(y_test, y_pred4,average='weighted'))
#
#
# from sklearn.metrics import f1_score
# print("f1_score : ",f1_score(y_test, y_pred4,average='weighted'))
